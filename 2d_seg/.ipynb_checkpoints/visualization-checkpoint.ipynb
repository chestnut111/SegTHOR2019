# %%
import pandas as pd 
import cv2
import os 
import imgaug as ia
from imgaug import augmenters as iaa
import imageio
import numpy as np

import matplotlib.pyplot as plt

from conf import train_config
from utils import *

data_folder = train_config.data_foler

# To prepare data
data_train = pd.read_csv(train_config.train_csv_path)
data_val = pd.read_csv(train_config.val_csv_path)

data_train_mb = data_train.loc[data_train[train_config.gt_class] == 1]
data_val_mb = data_val.loc[data_val[train_config.gt_class] == 1]

print(len(data_val_mb))
data_test = pd.read_csv(train_config.test_csv_path)
# Out:
# Using TensorFlow backend.
# 812
# /public/lixin/.local/lib/python3.6/site-packages/classification_models/resnext/__init__.py:4: UserWarning: Current ResNext models are deprecated, use keras.applications ResNeXt models
#   warnings.warn('Current ResNext models are deprecated, '

# %%
data_val_mb.head()
# Out:
#     Unnamed: 0                                         filename  \
# 68          68  train_fla/validates/01/images/Patient_01_68.png
# 69          69  train_fla/validates/01/images/Patient_01_69.png
# 70          70  train_fla/validates/01/images/Patient_01_70.png
# 71          71  train_fla/validates/01/images/Patient_01_71.png
# 72          72  train_fla/validates/01/images/Patient_01_72.png
#
#                                      maskname  folder  red  pink  yellow  \
# 68  train_fla/validates/01/masks/GT_01_68.png       1    1     0       0
# 69  train_fla/validates/01/masks/GT_01_69.png       1    1     0       0
# 70  train_fla/validates/01/masks/GT_01_70.png       1    1     0       0
# 71  train_fla/validates/01/masks/GT_01_71.png       1    1     0       0
# 72  train_fla/validates/01/masks/GT_01_72.png       1    1     0       0
#
#     blue  ys   ye  ...   xe    cyy    cyx  p_yellow    cry    crx    cpy  \
# 68     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
# 69     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
# 70     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
# 71     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
# 72     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
#
#       cpx    cby    cbx
# 68  264.0  253.0  252.0
# 69  264.0  253.0  252.0
# 70  264.0  253.0  252.0
# 71  264.0  253.0  252.0
# 72  264.0  253.0  252.0
#
# [5 rows x 21 columns]

# %%
data_train_mb.head()
# Out:
#     Unnamed: 0                                     filename  \
# 50          50  train_fla/train/05/images/Patient_05_50.png
# 51          51  train_fla/train/05/images/Patient_05_51.png
# 52          52  train_fla/train/05/images/Patient_05_52.png
# 53          53  train_fla/train/05/images/Patient_05_53.png
# 54          54  train_fla/train/05/images/Patient_05_54.png
#
#                                  maskname  folder  red  pink  yellow  blue  \
# 50  train_fla/train/05/masks/GT_05_50.png       5    1     1       0     1
# 51  train_fla/train/05/masks/GT_05_51.png       5    1     1       0     1
# 52  train_fla/train/05/masks/GT_05_52.png       5    1     1       0     1
# 53  train_fla/train/05/masks/GT_05_53.png       5    1     1       0     1
# 54  train_fla/train/05/masks/GT_05_54.png       5    1     1       0     1
#
#      ys   ye  xs   xe    cyy    cyx    cry    crx    cpy    cpx    cby    cbx
# 50  118  480  11  505  262.0  244.0  291.0  262.0  249.0  280.0  276.0  270.0
# 51  118  480  11  505  262.0  244.0  291.0  262.0  249.0  280.0  276.0  270.0
# 52  118  480  11  505  262.0  244.0  291.0  262.0  249.0  280.0  276.0  270.0
# 53  118  480  11  505  262.0  244.0  291.0  262.0  249.0  280.0  276.0  270.0
# 54  118  480  11  505  262.0  244.0  291.0  262.0  249.0  280.0  276.0  270.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # get data
#
# ![](1train_sample.png)

# %%
in_df = data_val.loc[data_val[train_config.gt_class] == 1]

# %%
in_df.head()
# Out:
#     Unnamed: 0                                         filename  \
# 68          68  train_fla/validates/01/images/Patient_01_68.png
# 69          69  train_fla/validates/01/images/Patient_01_69.png
# 70          70  train_fla/validates/01/images/Patient_01_70.png
# 71          71  train_fla/validates/01/images/Patient_01_71.png
# 72          72  train_fla/validates/01/images/Patient_01_72.png
#
#                                      maskname  folder  red  pink  yellow  \
# 68  train_fla/validates/01/masks/GT_01_68.png       1    1     0       0
# 69  train_fla/validates/01/masks/GT_01_69.png       1    1     0       0
# 70  train_fla/validates/01/masks/GT_01_70.png       1    1     0       0
# 71  train_fla/validates/01/masks/GT_01_71.png       1    1     0       0
# 72  train_fla/validates/01/masks/GT_01_72.png       1    1     0       0
#
#     blue  ys   ye  ...   xe    cyy    cyx  p_yellow    cry    crx    cpy  \
# 68     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
# 69     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
# 70     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
# 71     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
# 72     1  99  509  ...  494  244.0  258.0       0.0  260.0  254.0  207.0
#
#       cpx    cby    cbx
# 68  264.0  253.0  252.0
# 69  264.0  253.0  252.0
# 70  264.0  253.0  252.0
# 71  264.0  253.0  252.0
# 72  264.0  253.0  252.0
#
# [5 rows x 21 columns]

# %%
file = in_df.loc[in_df['folder']==34]

# %%
# file

# %%
file = file.sample(10)
file_name = file['filename'].values

# %%
file_name
# Out:
# array(['train_fla/validates/34/images/Patient_34_130.png',
#        'train_fla/validates/34/images/Patient_34_122.png',
#        'train_fla/validates/34/images/Patient_34_64.png',
#        'train_fla/validates/34/images/Patient_34_113.png',
#        'train_fla/validates/34/images/Patient_34_102.png',
#        'train_fla/validates/34/images/Patient_34_95.png',
#        'train_fla/validates/34/images/Patient_34_138.png',
#        'train_fla/validates/34/images/Patient_34_103.png',
#        'train_fla/validates/34/images/Patient_34_110.png',
#        'train_fla/validates/34/images/Patient_34_125.png'], dtype=object)

# %%
# help(in_df.sample)

# %%
import cv2 as cv
import matplotlib.pyplot as plt

fig, m_axs = plt.subplots(10, 2, figsize = (10, 80))
[c_ax.axis('off') for c_ax in m_axs.flatten()]


for (ax1, ax2), c_img_name in zip(m_axs, file_name):

    y = in_df.loc[in_df['filename'] == c_img_name][train_config.cy].values[0]
    x = in_df.loc[in_df['filename'] == c_img_name][train_config.cx].values[0]
    
    c_path = data_folder + c_img_name
    c_img = crop_center_pic(cv2.imread(c_path), int(y), int(x))
    
    c_path2 = data_folder.replace('pink-normal','pink-median') + c_img_name
    c_img2 = crop_center_pic(cv2.imread(c_path2), int(y), int(x))
    

    ax2.imshow(c_img)
    ax2.set_title('pink')
    
    ax1.imshow(c_img2)
    ax1.set_title('median')
# fig.savefig('52-pink.png')

# %%
import cv2 as cv
import matplotlib.pyplot as plt

fig, m_axs = plt.subplots(10, 2, figsize = (10, 80))
[c_ax.axis('off') for c_ax in m_axs.flatten()]


for (ax1, ax2), c_img_name in zip(m_axs, file_name):

    y = in_df.loc[in_df['filename'] == c_img_name][train_config.cy].values[0]
    x = in_df.loc[in_df['filename'] == c_img_name][train_config.cx].values[0]
    
    mask_path = in_df.loc[in_df['filename'] == c_img_name]['maskname'].values[0]
    
    c_path = data_folder + c_img_name
    c_img = crop_center_pic(cv2.imread(c_path), int(y), int(x))
    
    c_path2 = data_folder + mask_path
    c_img2 = crop_center_mask(cv2.imread(c_path2, 0), int(y), int(x))
    c_img2 = np.where(np.equal(c_img2, train_config.class_label), 1, 0)
    
    

    ax2.imshow(c_img)
    ax2.set_title('pink')
    
    ax1.imshow(c_img2)
    ax1.set_title('median')
# fig.savefig('52-pink.png')

# %%
file
# Out:
#                                         filename  folder  ys   ye  xs   xe  \
# 2078  train_fla/test/52/images/Patient_52_80.png      52  91  512   0  512
# 2062  train_fla/test/52/images/Patient_52_64.png      52  91  512   0  512
# 2091  train_fla/test/52/images/Patient_52_93.png      52  91  512   0  512
# 2068  train_fla/test/52/images/Patient_52_70.png      52  91  512   0  512
# 2079  train_fla/test/52/images/Patient_52_81.png      52  91  512   0  512
# 2076  train_fla/test/52/images/Patient_52_78.png      52  91  512   0  512
# 2082  train_fla/test/52/images/Patient_52_84.png      52  91  512   0  512
# 2069  train_fla/test/52/images/Patient_52_71.png      52  91  512   0  512
# 2063  train_fla/test/52/images/Patient_52_65.png      52  91  512   0  512
# 2070  train_fla/test/52/images/Patient_52_72.png      52  91  512   0  512
#
#       p_pink    cyy    cyx  p_yellow    cry    crx    cpy    cpx
# 2078     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0
# 2062     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0
# 2091     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0
# 2068     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0
# 2079     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0
# 2076     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0
# 2082     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0
# 2069     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0
# 2063     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0
# 2070     1.0  260.0  266.0       0.0  272.0  262.0  232.0  284.0

# %%
# image_path = in_df['filename'].values[0]
# mask_path = in_df['maskname'].values[0]


# image_path = 'train_fla/validates/05/images/Patient_05_64.png'
# mask_path = 'train_fla/validates/05/masks/GT_05_64.png'

# y = in_df.loc[in_df['filename'] == image_path]['cry'].values[0]
# x = in_df.loc[in_df['filename'] == image_path]['crx'].values[0]

image_path  = file['filename'].values[0]
mask_path  = file['maskname'].values[0]

y = file[config].values[0]
x = file['cpx'].values[0]

print(y, x)
file = data_folder + image_path  
mask = data_folder + mask_path


print(file)
print(mask)
c_img = crop_center_pic(cv2.imread(file), int(y), int(x))
c_mask = crop_center_mask(cv2.imread(mask, 0), int(y), int(x))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/py36_tensorflow-1.12.2/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maskname'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-780f25cd7fb7> in <module>
#      10
#      11 image_path  = file['filename'].values[0]
# ---> 12 mask_path  = file['maskname'].values[0]
#      13
#      14 y = file['cpy'].values[0]
#
# /opt/anaconda3/envs/py36_tensorflow-1.12.2/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /opt/anaconda3/envs/py36_tensorflow-1.12.2/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maskname'

# %%
plt.imshow(np.where(np.equal(c_mask, 2), 1, 0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2af5e02a8014> in <module>
# ----> 1 plt.imshow(np.where(np.equal(c_mask, 2), 1, 0))
#
# NameError: name 'c_mask' is not defined

# %%
plt.imshow(c_img)

# %% [markdown]
# # c_img, c_mask

# %%
mask = '/public/lixin/DATA/segthor/input/blue/train_fla/train/35/masks/GT_35_0.png'
img = cv2.imread(mask, 0)
img
plt.imshow(img)

# %%
mask = '/public/lixin/DATA/segthor/input/blue/train_fla/train/35/images/Patient_35_0.png'
img = cv2.imread(mask)
img
plt.imshow(img)
