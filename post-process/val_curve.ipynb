# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


sns.set(style="whitegrid")
plt.subplots(figsize = (10, 8))
# pink
# p320_256 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try320-256-2/pink320.csv'
# p320 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try320-2/pink320-2.csv'
# p288 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try288-2/pink288-2.csv'
# p256 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try256-2/pink256-2.csv'

# yellow
p320_256 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try320-256-yellow/yellow256.csv'
p320_h = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try320-256-yellow/yellow320.csv'

p320 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try320-yellow/yellow320.csv'
p288 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try288-yellow/yellow288.csv'
p256 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try256-yellow/yellow256.csv'

one = pd.read_csv(p320_256)['val_dice_coef'].values
two = pd.read_csv(p320)['val_dice_coef'].values
thr = pd.read_csv(p288)['val_dice_coef'].values
fou = pd.read_csv(p256)['val_dice_coef'].values

h = pd.read_csv(p320_h)['val_dice_coef'].values

max_len = np.max(np.array([len(one), len(two), len(thr), len(fou)]))
print(max_len)
x1 = [np.nan]*max_len
x2 = [np.nan]*max_len
x3 = [np.nan]*max_len
x4 = [np.nan]*max_len

# x1[:10] = h
x1[0:len(one)] = one
x2[:len(two)] = two
x3[:len(thr)] = thr
x4[:len(fou)] = fou

dic = {'320-256':x1 ,
      '320':x2,
      '288':x3,
      '256':x4}

data = pd.DataFrame(dic)
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# 100

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


sns.set(style="whitegrid")
plt.subplots(figsize = (10, 8))



# yellow
p96 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try96-red/red96.csv'


one = pd.read_csv(p96)['val_dice_coef'].values
two = pd.read_csv(p96)['dice_coef'].values

dic = {'val_dice':one ,
      'train_dice':two,
                }

data = pd.DataFrame(dic)
data = data.rolling(10).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)

# %%
sns.set(style="whitegrid")
plt.subplots(figsize = (10, 8))
# yellow
p224 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try224-red/red224.csv'

p22 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try224-red/red160-no-fre.csv'


one = pd.read_csv(p224)['val_dice_coef'].values
two = pd.read_csv(p224)['dice_coef'].values

one2 = pd.read_csv(p22)['val_dice_coef'].values
two2 = pd.read_csv(p22)['dice_coef'].values

max_len = 100
x1 = [np.nan]*max_len
x2 = [np.nan]*max_len
x3 = [np.nan]*max_len
x4 = [np.nan]*max_len

# x1[:10] = h
x1[0:len(one)] = one[:100]
x2[0:len(two)] = two[:100]
x3[0:len(one2)] = one2
x4[0:len(two2)] = two2

print(len(x1), len(x2), len(x3), len(x4))
dic = {'val_dice224':x1 ,
      'train_dice224':x2,
       'val_dice224-160':x3 ,
      'train_dice224-160':x4,
                }

data = pd.DataFrame(dic)
# data = data.rolling(10).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# 100 100 100 100

# %%
sns.set(style="whitegrid")
plt.subplots(figsize = (10, 8))
# yellow
p224 = '/public/lixin/SegTHOR/segthor/2d_seg/model_save/densenet121/try224-red-normal/red224_160.csv'


one = pd.read_csv(p224)['val_dice_coef'].values
two = pd.read_csv(p224)['dice_coef'].values

dic = {'val_dice':one ,
      'train_dice':two,
                }

data = pd.DataFrame(dic)
# data = data.rolling(10).mean()


sns.lineplot(data=data, palette="tab10", linewidth=2.5)
